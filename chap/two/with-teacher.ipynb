# %%
import mglearn
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X, y = mglearn.datasets.make_forge()
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
plt.legend(["Class 0", "Class 1"], loc=4)
plt.xlabel("First feature")
plt.ylabel("Second feature")
print(f"X.shape: {X.shape}")
# Out:
# X.shape: (26, 2)

# %%
df = pd.DataFrame(X, columns=["feature_1", "feature_2"])
df["label"] = y
df["label"] = df["label"].replace({0: "Class 0", 1: "Class 1"})
print(df.head())
sns.scatterplot(data=df, x="feature_1", y="feature_2", hue="label",
                palette=["red", "green"], s=80, edgecolor="k")
# Out:
#    feature_1  feature_2    label
# 0   9.963466   4.596765  Class 1
# 1  11.032954  -0.168167  Class 0
# 2  11.541558   5.211161  Class 1
# 3   8.692890   1.543220  Class 0
# 4   8.106227   4.286960  Class 0
# <Axes: xlabel='feature_1', ylabel='feature_2'>
